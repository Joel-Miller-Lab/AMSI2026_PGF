# %% [markdown]
# # Early Outbreak Stage and Galton-Watson Processes
#
# In the infinite population limit of a well-mixed population, starting from a single infected individual, we can assume that every transmission (at every generation) goes to a previously uninfected recipient.  Thus every transmission causes an infection, regardless of whether it is an SIS or SIR disease.  The SIS and SIR diseases are mathematically indistinguishable in this case, and the number of infections caused by each individual is chosen independently from the offspring distribution.
#
# ```{prf:theorem}
# :label: InfDisGaltWat
# If:
# - an infectious disease outbreak begins with a single infected individual (the *index case* ) counted as generation $0$,
# - the infections are separated by generation so that those infected by generation $g$ are considered to be in generation $g$,
# - the number of transmissions caused by each infected individual is independent of all others and has PGF $\mu(x)$.
# - the population is large enough that every transmission goes to a new never-before infected individual,
#
# Then the number of infections at generation $g$ forms a Galton-Watson process with offspring distribution $\mu(x)$.  If we generate edges from infector to infectee, we get a Galton-Watson tree.
# ```
#
# To prove this, we show that the definition of a Galton-Watson process {prf:ref}`def-GaltonWatson` is satisfied.
#
# We must show that the number of infections $X_g$ in generation $g$ is a sequence of random numbers $\{X_g\}_{g \in \mathbb{N}}$ such that $X_0=1$ and $X_{g+1} = \sum_{j=1}^{X_g} k_{j,g}$ where each $k_{j,g}$ is chosen independently from the offspring distribution.
#
# - The fact that $X_0=1$ follows from the assumption of a single index case.
# - For each of the $X_g$ infected individuals in generation $g$, the number of transmissions caused is chosen independently from the offspring distribution.  Thus $X_{g+1} = \sum_{j=1}^{X_g} k_{j,g}$ where $k_{j,g}$ is chosen independently from the offspring distribution.
#
# Thus the definition of a Galton-Watson process is satisfied.  The connection to a Galton-Watson tree is straightforward.

# %% [markdown]
# ## Consequences for infectious disease models
#
# As a result, if we model infection in a large well-mixed population starting from a single index case, we immediately inherit results about Galton-Watson processes.
#
# ...
