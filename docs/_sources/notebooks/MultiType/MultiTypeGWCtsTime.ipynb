# %% [markdown]
# # Continuous-time framework
# We now adopt a continuous-time framework where $\Phi(x,y,t|(1,0))$ is the PGF for $X(t),Y(t)$ assuming $(X(0),Y(0))=(1,0)$.
#
# I have not written this section, but you can follow the work done in {ref}`sec:carcinogenesis` {numref}`sec:carcinogenesis`.
